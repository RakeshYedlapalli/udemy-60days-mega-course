# %% [markdown]
# # Load the dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv("data_small/TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      1
# 1          1   35381 1860-01-02     46      1
# 2          1   35381 1860-01-03     31      1
# 3          1   35381 1860-01-04     37      1
# 4          1   35381 1860-01-05     31      1
# ...      ...     ...        ...    ...    ...
# 59469      1   35381 2022-10-27  -9999      9
# 59470      1   35381 2022-10-28  -9999      9
# 59471      1   35381 2022-10-29  -9999      9
# 59472      1   35381 2022-10-30  -9999      9
# 59473      1   35381 2022-10-31  -9999      9
#
# [59474 rows x 5 columns]

# %%
# Show certain commands

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      1
# 11      1   35381 1860-01-12    -18      1
# 12      1   35381 1860-01-13    -27      1
# 13      1   35381 1860-01-14    -26      1
# 14      1   35381 1860-01-15    -37      1
# 15      1   35381 1860-01-16     -9      1
# 16      1   35381 1860-01-17      7      1
# 17      1   35381 1860-01-18     -6      1
# 18      1   35381 1860-01-19    -16      1
# 19      1   35381 1860-01-20    -19      1

# %% [markdown]
# # Show certain columns only

# %%
df[["   TG",'    DATE']]
# Out:
#           TG       DATE
# 0         21 1860-01-01
# 1         46 1860-01-02
# 2         31 1860-01-03
# 3         37 1860-01-04
# 4         31 1860-01-05
# ...      ...        ...
# 59469  -9999 2022-10-27
# 59470  -9999 2022-10-28
# 59471  -9999 2022-10-29
# 59472  -9999 2022-10-30
# 59473  -9999 2022-10-31
#
# [59474 rows x 2 columns]

# %%
df["   TG"].mean()
# Out:
# -1014.323233681945

# %%
df.loc[df["   TG"] != -9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      1
# 1          1   35381 1860-01-02     46      1
# 2          1   35381 1860-01-03     31      1
# 3          1   35381 1860-01-04     37      1
# 4          1   35381 1860-01-05     31      1
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
df.loc[df["   TG"] != 9999]["   TG"].hist()
# Out:
# <Axes: >

# %%
df.loc[df['    DATE']=="1860-01-05"]
# Out:
#    STAID   SOUID       DATE     TG   Q_TG
# 4      1   35381 1860-01-05     31      1

# %%
df["TG"] = df["   TG"]/10

# %%
bdf
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG
# 0          1   35381 1860-01-01     21      1    2.1
# 1          1   35381 1860-01-02     46      1    4.6
# 2          1   35381 1860-01-03     31      1    3.1
# 3          1   35381 1860-01-04     37      1    3.7
# 4          1   35381 1860-01-05     31      1    3.1
# ...      ...     ...        ...    ...    ...    ...
# 59469      1   35381 2022-10-27  -9999      9 -999.9
# 59470      1   35381 2022-10-28  -9999      9 -999.9
# 59471      1   35381 2022-10-29  -9999      9 -999.9
# 59472      1   35381 2022-10-30  -9999      9 -999.9
# 59473      1   35381 2022-10-31  -9999      9 -999.9
#
# [59474 rows x 6 columns]

# %%
import numpy as np
df["TG0"] = df['   TG'].mask(df['   TG']==-9999, np.nan)

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG   TG0
# 0          1   35381 1860-01-01     21      1    2.1  21.0
# 1          1   35381 1860-01-02     46      1    4.6  46.0
# 2          1   35381 1860-01-03     31      1    3.1  31.0
# 3          1   35381 1860-01-04     37      1    3.7  37.0
# 4          1   35381 1860-01-05     31      1    3.1  31.0
# ...      ...     ...        ...    ...    ...    ...   ...
# 59469      1   35381 2022-10-27  -9999      9 -999.9   NaN
# 59470      1   35381 2022-10-28  -9999      9 -999.9   NaN
# 59471      1   35381 2022-10-29  -9999      9 -999.9   NaN
# 59472      1   35381 2022-10-30  -9999      9 -999.9   NaN
# 59473      1   35381 2022-10-31  -9999      9 -999.9   NaN
#
# [59474 rows x 7 columns]

# %%
df["TG"] = df["TG0"]/10

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG   TG0
# 0          1   35381 1860-01-01     21      1  2.1  21.0
# 1          1   35381 1860-01-02     46      1  4.6  46.0
# 2          1   35381 1860-01-03     31      1  3.1  31.0
# 3          1   35381 1860-01-04     37      1  3.7  37.0
# 4          1   35381 1860-01-05     31      1  3.1  31.0
# ...      ...     ...        ...    ...    ...  ...   ...
# 59469      1   35381 2022-10-27  -9999      9  NaN   NaN
# 59470      1   35381 2022-10-28  -9999      9  NaN   NaN
# 59471      1   35381 2022-10-29  -9999      9  NaN   NaN
# 59472      1   35381 2022-10-30  -9999      9  NaN   NaN
# 59473      1   35381 2022-10-31  -9999      9  NaN   NaN
#
# [59474 rows x 7 columns]

# %% [markdown]
# # Plotting

# %%
df["TG"].hist()
# Out:
# <Axes: >

# %%
df.plot(x='    DATE', y="TG", figsize=(15,3))
# Out:
# <Axes: xlabel='    DATE'>

# %%
df[100:1000].plot(x='    DATE', y="TG", figsize=(15,3))
# Out:
# <Axes: xlabel='    DATE'>
